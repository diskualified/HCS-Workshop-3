# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import math

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
#digits = np.loadtxt('./semeion.data')

# %%
digits = datasets.load_digits()

# Create the features matrix
X = digits.data

# Create the target vector
y = digits.target

# %%
def print_drawing(drawing):
    plt.gray() 
    plt.matshow(drawing) 
    plt.show() 

for drawing in digits.images:
    print_drawing(drawing)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-fbaeb14573d8> in <module>()
#       5
#       6 for drawing in digits.images:
# ----> 7     print_drawing(drawing)
#
# <ipython-input-4-fbaeb14573d8> in print_drawing(drawing)
#       2     plt.gray()
#       3     plt.matshow(drawing)
# ----> 4     plt.show()
#       5
#       6 for drawing in digits.images:
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/IPython/core/display.py in display(*objs, **kwargs)
#     309             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     310         else:
# --> 311             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     312             if not format_dict:
#     313                 # nothing to display (e.g. _ipython_display_ took over)
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     171             md = None
#     172             try:
# --> 173                 data = formatter(obj)
#     174             except:
#     175                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     215     """show traceback on failed format call"""
#     216     try:
# --> 217         r = method(self, *args, **kwargs)
#     218     except NotImplementedError:
#     219         # don't warn on NotImplementedErrors
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     129
#     130     bytes_io = BytesIO()
# --> 131     fig.canvas.print_figure(bytes_io, **kw)
#     132     data = bytes_io.getvalue()
#     133     if fmt == 'svg':
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     515
#     516     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 517         FigureCanvasAgg.draw(self)
#     518         renderer = self.get_renderer()
#     519         original_dpi = renderer.dpi
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1193
#    1194         for tick in ticks_to_draw:
# -> 1195             tick.draw(renderer)
#    1196
#    1197         # scale up the axis label box to also find the neighbors, not
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer)
#     302
#     303         if self.label1On:
# --> 304             self.label1.draw(renderer)
#     305         if self.label2On:
#     306             self.label2.draw(renderer)
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     721                 textobj._draw_bbox(renderer, posx, posy)
#     722
# --> 723             gc = renderer.new_gc()
#     724             gc.set_foreground(textobj.get_color())
#     725             gc.set_alpha(textobj.get_alpha())
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/backend_bases.py in new_gc(self)
#     789         Return an instance of a :class:`GraphicsContextBase`
#     790         """
# --> 791         return GraphicsContextBase()
#     792
#     793     def points_to_pixels(self, points):
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/backend_bases.py in __init__(self)
#     860         self._rgb = (0.0, 0.0, 0.0, 1.0)
#     861         self._hatch = None
# --> 862         self._hatch_color = colors.to_rgba(rcParams['hatch.color'])
#     863         self._hatch_linewidth = rcParams['hatch.linewidth']
#     864         self._url = None
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     161     """
#     162     # Special-case nth color syntax because it should not be cached.
# --> 163     if _is_nth_color(c):
#     164         from matplotlib import rcParams
#     165         prop_cycler = rcParams['axes.prop_cycle']
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/colors.py in _is_nth_color(c)
#     110 def _is_nth_color(c):
#     111     """Return whether *c* can be interpreted as an item in the color cycle."""
# --> 112     return isinstance(c, six.string_types) and re.match(r"\AC[0-9]\Z", c)
#     113
#     114
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/re.py in match(pattern, string, flags)
#     173     """Try to apply the pattern at the start of the string, returning
#     174     a Match object, or None if no match was found."""
# --> 175     return _compile(pattern, flags).match(string)
#     176
#     177 def fullmatch(pattern, string, flags=0):
#
# /Users/davidqian/anaconda3/envs/tf/lib/python3.7/re.py in _compile(pattern, flags)
#     276         flags = flags.value
#     277     try:
# --> 278         return _cache[type(pattern), pattern, flags]
#     279     except KeyError:
#     280         pass
#
# KeyboardInterrupt:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.1, 
                                                    random_state=1)

# %%
standardizer = StandardScaler()

# Fit standardizer to training set
standardizer.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_std = standardizer.transform(X_train)
X_test_std = standardizer.transform(X_test)

# %%
model = keras.models.Sequential()

# adding the first hidden layer
model.add(layers.Dense(512, input_shape=(64,)))
model.add(layers.Activation('relu'))                            
model.add(layers.Dropout(0.2))

# adding the second hidden layer
model.add(layers.Dense(512))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.2))

# adding the output layer
model.add(layers.Dense(10))
model.add(layers.Activation('softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
history = model.fit(X_train_std, y_train,
          batch_size=128, epochs=20,
          verbose=2,
          validation_data=(X_test_std, y_test))
# Out:
# Train on 1617 samples, validate on 180 samples
# Epoch 1/20
# 1617/1617 - 1s - loss: 1.1420 - accuracy: 0.7236 - val_loss: 0.3431 - val_accuracy: 0.9000
# Epoch 2/20
# 1617/1617 - 0s - loss: 0.2459 - accuracy: 0.9332 - val_loss: 0.1269 - val_accuracy: 0.9611
# Epoch 3/20
# 1617/1617 - 0s - loss: 0.1191 - accuracy: 0.9610 - val_loss: 0.0859 - val_accuracy: 0.9722
# Epoch 4/20
# 1617/1617 - 0s - loss: 0.0766 - accuracy: 0.9796 - val_loss: 0.0784 - val_accuracy: 0.9833
# Epoch 5/20
# 1617/1617 - 0s - loss: 0.0507 - accuracy: 0.9895 - val_loss: 0.0622 - val_accuracy: 0.9833
# Epoch 6/20
# 1617/1617 - 0s - loss: 0.0394 - accuracy: 0.9913 - val_loss: 0.0608 - val_accuracy: 0.9833
# Epoch 7/20
# 1617/1617 - 0s - loss: 0.0292 - accuracy: 0.9938 - val_loss: 0.0578 - val_accuracy: 0.9833
# Epoch 8/20
# 1617/1617 - 0s - loss: 0.0275 - accuracy: 0.9932 - val_loss: 0.0523 - val_accuracy: 0.9889
# Epoch 9/20
# 1617/1617 - 0s - loss: 0.0186 - accuracy: 0.9975 - val_loss: 0.0340 - val_accuracy: 0.9833
# Epoch 10/20
# 1617/1617 - 0s - loss: 0.0150 - accuracy: 0.9988 - val_loss: 0.0288 - val_accuracy: 0.9889
# Epoch 11/20
# 1617/1617 - 0s - loss: 0.0127 - accuracy: 0.9988 - val_loss: 0.0388 - val_accuracy: 0.9833
# Epoch 12/20
# 1617/1617 - 0s - loss: 0.0086 - accuracy: 0.9994 - val_loss: 0.0379 - val_accuracy: 0.9833
# Epoch 13/20
# 1617/1617 - 0s - loss: 0.0080 - accuracy: 0.9988 - val_loss: 0.0280 - val_accuracy: 0.9944
# Epoch 14/20
# 1617/1617 - 0s - loss: 0.0092 - accuracy: 0.9988 - val_loss: 0.0312 - val_accuracy: 0.9944
# Epoch 15/20
# 1617/1617 - 0s - loss: 0.0068 - accuracy: 0.9994 - val_loss: 0.0265 - val_accuracy: 0.9944
# Epoch 16/20
# 1617/1617 - 0s - loss: 0.0068 - accuracy: 0.9994 - val_loss: 0.0370 - val_accuracy: 0.9833
# Epoch 17/20
# 1617/1617 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9889
# Epoch 18/20
# 1617/1617 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9889
# Epoch 19/20
# 1617/1617 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9944
# Epoch 20/20
# 1617/1617 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9889
